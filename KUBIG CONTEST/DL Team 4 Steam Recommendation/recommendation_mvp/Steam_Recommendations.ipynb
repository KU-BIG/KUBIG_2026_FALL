# %% [markdown]
# <a href="https://colab.research.google.com/github/Hong-Junki/26_2_Contest/blob/main/Steam_Recommendations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Steam
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Steam
# 01_download.py		    emb_resnet18_pad.npy
# 02_audit.py		    emb_resnet18_squash.csv
# 03_extract_embeddings.py    emb_resnet18_squash.npy
# 04_diagnose.py		    flagged_images.csv
# 05_linear_probe.py	    games.csv
# 06_metadata_baseline.py     games_metadata.json
# 07_image_tower.py	    image_audit.csv
# 08_interaction_eda.py	    images.tar
# download_report.csv	    probe_grouped_emb_clip_plus_resnet.csv
# duplicate_images.csv	    probe_grouped_emb_clip_squash.csv
# emb_clip_plus_resnet.csv    probe_grouped_emb_meta.csv
# emb_clip_plus_resnet.npy    probe_grouped_emb_meta_plus_clip.csv
# emb_clip_plus_shuffled.csv  probe_log.csv
# emb_clip_plus_shuffled.npy  probe_meta_vs_image.csv
# emb_clip_squash.csv	    probe_per_label_emb_clip_plus_resnet.csv
# emb_clip_squash.npy	    probe_per_label_emb_clip_squash.csv
# ...

# %%
# 파일 추가 후 로딩 코드

# %cd "/content/drive/MyDrive/Steam"
# !ls -l 08_interaction_eda.py

# %%
# !python 08_interaction_eda.py --data-dir /content/drive/MyDrive/Steam
# Out:
#   chunk   0  누적 2,000,000 행
#   chunk   1  누적 4,000,000 행
#   chunk   2  누적 6,000,000 행
#   chunk   3  누적 8,000,000 행
#   chunk   4  누적 10,000,000 행
#   chunk   5  누적 12,000,000 행
#   chunk   6  누적 14,000,000 행
#   chunk   7  누적 16,000,000 행
#   chunk   8  누적 18,000,000 행
#   chunk   9  누적 20,000,000 행
#   chunk  10  누적 22,000,000 행
#   chunk  11  누적 24,000,000 행
#   chunk  12  누적 26,000,000 행
#   chunk  13  누적 28,000,000 행
#   chunk  14  누적 30,000,000 행
#   chunk  15  누적 32,000,000 행
#   chunk  16  누적 34,000,000 행
#   chunk  17  누적 36,000,000 행
#   chunk  18  누적 38,000,000 행
#   chunk  19  누적 40,000,000 행
#   chunk  20  누적 41,154,794 행
#
# ...
# 총 상호작용 41,154,794 | 유저 13,781,059 | 게임 37,610
# is_recommended = True 비율: 0.8578
# 밀도(sparsity): 7.94e-05
#
# --- 유저별 상호작용 수 분포 ---
#   평균 2.99 | 중앙값 1 | 최대 6045
#   p50    1
#   p75    3
#   p90    6
#   p95    9
#   p99    25
#   p99.9  79
#
# --- k-core 기준별 생존 규모 (단일 패스 근사) ---
#     k         유저 수     유저 비율           상호작용      비율
# ...
